# %%
import ctaplot
from ctaplot.dataset import get
import matplotlib.pyplot as plt
import matplotlib

# %%
# %matplotlib inline

# %%
font = {'size'   : 20}
matplotlib.rc('font', **font)

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = ctaplot.plot_angular_res_requirement('north', ax=ax)

plt.legend(prop = font)
