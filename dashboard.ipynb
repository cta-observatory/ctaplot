# %%
# %matplotlib notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import gammaboard as gabo
gb = gabo.GammaBoard('/home/mikael/gammaLearn_experiments/experiments')
# Out:
# <img src="data:image/png;base64,..." width="1199.9166666666667">

# %%
gb.exp_box
# Out:
# HBox(children=(VBox(children=(Button(button_style='warning', description='R_0140', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0139', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0138', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0137', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0136', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0135', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0134', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0133', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0132', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0131', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0130', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0129', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0128', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0127', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0126', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0125', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0124', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0123', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0122', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0121', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0120_test_point_source_cut_amplitude_multi', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0120', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0119_test_point_source_nocut', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0119_test_point_source_cuts', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0119_test_point_source_cut_amplitude_multi', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0119_test_point_source_cut_amplitude', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0119', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0118', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0117', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0116', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0115', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Bu ...

# %%
exp = gb.experiments_dict['R_0137']
exp.load_data()
fig = gabo.plot_migration_matrices(exp, figsize=(20,4))
# Out:
# <img src="data:image/png;base64,..." width="1999.2500000000002">

# %%
exp.data
