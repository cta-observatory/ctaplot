# %%
# %matplotlib notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import gammaboard as gabo
gb = gabo.GammaBoard('/home/mikael/gammaLearn_experiments/experiments/', site='south', ref='performances') # ref can also be None or 'requirements'
# gb = gabo.GammaBoard('/home/mikael/lst_bootcamp_gl_data/')
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
gb.exp_box
# Out:
# HBox(children=(VBox(children=(Button(button_style='warning', description='test_gradnorm_2', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='test_gradnorm', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='bmm_nograd', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='bench_pt10', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='bench_matmul', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='bench_bmm', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_RF_20190402_cuts', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_RF_20190402', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_RF_20190311', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0240', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0239', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0238', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0235', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0234', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0233', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0232', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0231', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0230', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0229', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0228', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0227', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0226', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0225', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0224', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0223', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0222', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0221', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0220', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0219', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0218', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0217', layout=Layout(min_height='30px', width='auto'), style=ButtonStyle()), Button(button_style='warning', description='R_0216', layout=Layout(min_height='30px', width='auto' ...

# %%
exp = gb.experiments_dict['R_0220']
exp.load_data()
fig = gabo.plot_migration_matrices(exp, figsize=(20,4))

# %%
import numpy as np
import matplotlib.pyplot as plt
import ctaplot

# %%
f = plt.figure()
plt.hist(np.log10(exp.data.reco_energy), bins=50);

# %%
f =plt.figure()
ctaplot.plot_energy_bias(exp.data.mc_energy, exp.data.reco_energy)
plt.show()

# %%
f =plt.figure()
ctaplot.plot_energy_resolution(exp.data.mc_energy, exp.data.reco_energy, bias_correction=False)
ctaplot.plot_energy_resolution(exp.data.mc_energy, exp.data.reco_energy, bias_correction=True)
ctaplot.plot_energy_resolution_requirements('south')
ctaplot.plot_energy_resolution_cta_performances('south')
plt.show()

# %%
energy_error = exp.data.mc_energy - exp.data.reco_energy
fig = plt.figure()
n, bins, patches = plt.hist(energy_error, bins=1000)
plt.show()

# %%
energy_error.max()

# %%
energy_error.min()

# %%
exp.data
